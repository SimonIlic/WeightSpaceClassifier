# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from tqdm import tqdm
import pandas as pd

from cnn_surgery.lenses.regressor_lens import get_regressor_lens, mse_mae
from cnn_surgery.utils.evaluate_per_class_accuracy import evaluate_classifier, load_testset_data
from cnn_surgery.utils.load_dataset import load_dataset, load_multi_stage_dataset, find_best_model_index
from cnn_surgery.utils.reconstruct_network import reconstruct_network

DATASET = "fashion_mnist"

# %%
def test_network_accuracy(weights: np.ndarray | torch.Tensor, activation_fn):
    """
    Reconstructs a network from weights and activation function, evaluates it on the test set
    BEWARE: when using it in unlearning, the input could be a tensor, so be sure to convert it to numpy array first:
        weights = weights.detach().numpy()

    Returns:
        mean accuracy: float
        per class accuracies: list of floats
    """

    if isinstance(weights, torch.Tensor):
        weights = weights.detach().numpy()

    CNNModel = reconstruct_network(weights, activation_fn)
    # this returns a Keras model (Unterthiner code), we have to compile it first
    CNNModel.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    x_test, y_test = load_testset_data(DATASET)
    overall_acc, class_accs = evaluate_classifier(CNNModel, x_test, y_test)
    return overall_acc, class_accs

# %% [markdown]
# Visualize data samples from the dataset.

# %%
x_test, y_test = load_testset_data(DATASET)

figure, axes = plt.subplots(2, 5, figsize=(10, 5))
for i in range(10):
    label = i
    mask = y_test == label
    samples = x_test[np.argwhere(mask)]
    sample = samples[np.random.randint(len(samples))][0] # starts with a nonce dimension for some reason
    ax = axes[i // 5, i % 5]
    ax.imshow(sample, cmap='gray')
    ax.set_title(f"Label: {label}")
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# Load dataset and train model

# %%
train, val, test = load_multi_stage_dataset(include_test=True, dataset=DATASET).values()

weights_train = train[0]
weights_val = val[0]
weights_test = test[0]

accuracies_train = train[1]
accuracies_val = val[1]
accuracies_test = test[1]

configs_train = train[2]
configs_val = val[2]
configs_test = test[2]

RegressorLens = get_regressor_lens(weights_train, accuracies_train, weights_val, accuracies_val, device='cpu')
# save RegressorLens
torch.save(RegressorLens.state_dict(), f'regressor_lens_{DATASET}.pt')
# Out:
# WARNING:root:WARNING: The test set is being included in the returned data. Do NOT use the test set for model development, hyperparameter tuning, or any experiment selection. The test set should only be used once for final evaluation to report unbiased performance.
# dirname:  /Users/moos/Desktop/snijzaal/WeightSpaceClassifier/model_zoo/fashion_mnist
# WARNING:root:Using default seed 123 for shuffling. This results in the canonical train/test/val splits for this project. If a random split is desired, please use a different seed.
# dirname:  /Users/moos/Desktop/snijzaal/WeightSpaceClassifier/model_zoo/fashion_mnist
# WARNING:root:Using default seed 123 for shuffling. This results in the canonical train/test/val splits for this project. If a random split is desired, please use a different seed.
# dirname:  /Users/moos/Desktop/snijzaal/WeightSpaceClassifier/model_zoo/fashion_mnist
# WARNING:root:Using default seed 123 for shuffling. This results in the canonical train/test/val splits for this project. If a random split is desired, please use a different seed.
# Starting training of RegressorLens:
# Epoch   1 ─ val loss 0.026786 | val MAE 0.101485 | duration 1.8s
# Epoch   2 ─ val loss 0.022794 | val MAE 0.090464 | duration 1.2s
# Epoch   3 ─ val loss 0.021372 | val MAE 0.087119 | duration 1.1s
# Epoch   4 ─ val loss 0.021027 | val MAE 0.084909 | duration 1.1s
# Epoch   5 ─ val loss 0.020218 | val MAE 0.084215 | duration 1.1s
# Epoch   6 ─ val loss 0.019692 | val MAE 0.080880 | duration 1.4s
# Epoch   7 ─ val loss 0.019234 | val MAE 0.078244 | duration 1.3s
# Epoch   8 ─ val loss 0.019338 | val MAE 0.080902 | duration 1.3s
# Epoch   9 ─ val loss 0.019410 | val MAE 0.077330 | duration 1.1s
# Epoch  10 ─ val loss 0.018759 | val MAE 0.076944 | duration 1.1s
# Epoch  11 ─ val loss 0.018622 | val MAE 0.075915 | duration 1.1s
# Epoch  12 ─ val loss 0.018342 | val MAE 0.076555 | duration 1.2s
# Epoch  13 ─ val loss 0.018308 | val MAE 0.075107 | duration 1.1s
# Epoch  14 ─ val loss 0.019018 | val MAE 0.075562 | duration 1.3s
# Epoch  15 ─ val loss 0.018263 | val MAE 0.074211 | duration 1.1s
# Epoch  16 ─ val loss 0.017863 | val MAE 0.075317 | duration 1.2s
# Epoch  17 ─ val loss 0.017894 | val MAE 0.074332 | duration 1.5s
# Epoch  18 ─ val loss 0.017819 | val MAE 0.073549 | duration 1.4s
# Epoch  19 ─ val loss 0.017561 | val MAE 0.072875 | duration 1.2s
# Epoch  20 ─ val loss 0.017464 | val MAE 0.072853 | duration 1.2s
# Epoch  21 ─ val loss 0.017496 | val MAE 0.072205 | duration 1.1s
# Epoch  22 ─ val loss 0.017255 | val MAE 0.071647 | duration 1.2s
# Epoch  23 ─ val loss 0.017173 | val MAE 0.071760 | duration 1.1s
# Epoch  24 ─ val loss 0.017229 | val MAE 0.072325 | duration 1.3s
# Epoch  25 ─ val loss 0.016762 | val MAE 0.071126 | duration 1.1s
# Epoch  26 ─ val loss 0.018804 | val MAE 0.075050 | duration 1.1s
# Epoch  27 ─ val loss 0.017831 | val MAE 0.075151 | duration 1.1s
# Epoch  28 ─ val loss 0.017965 | val MAE 0.072660 | duration 1.1s
# Epoch  29 ─ val loss 0.016853 | val MAE 0.070777 | duration 1.3s
# Epoch  30 ─ val loss 0.016591 | val MAE 0.070293 | duration 1.4s
# Epoch  31 ─ val loss 0.016437 | val MAE 0.069765 | duration 1.2s
# Epoch  32 ─ val loss 0.016665 | val MAE 0.070762 | duration 1.3s
# Epoch  33 ─ val loss 0.016381 | val MAE 0.069742 | duration 1.2s
# Epoch  34 ─ val loss 0.016290 | val MAE 0.068911 | duration 1.2s
# Epoch  35 ─ val loss 0.016427 | val MAE 0.069894 | duration 1.2s
# Epoch  36 ─ val loss 0.016585 | val MAE 0.069811 | duration 1.2s
# Epoch  37 ─ val loss 0.016362 | val MAE 0.068794 | duration 1.1s
# Epoch  38 ─ val loss 0.016410 | val MAE 0.070768 | duration 1.1s
# Epoch  39 ─ val loss 0.016711 | val MAE 0.070395 | duration 1.2s
# Epoch  40 ─ val loss 0.016170 | val MAE 0.069662 | duration 1.1s
# Epoch  41 ─ val loss 0.016132 | val MAE 0.068839 | duration 1.1s
# Epoch  42 ─ val loss 0.016410 | val MAE 0.070360 | duration 1.2s
# Epoch  43 ─ val loss 0.016218 | val MAE 0.069839 | duration 1.1s
# Epoch  44 ─ val loss 0.016219 | val MAE 0.069163 | duration 1.2s
# Epoch  45 ─ val loss 0.016619 | val MAE 0.069375 | duration 1.1s
# Epoch  46 ─ val loss 0.016614 | val MAE 0.069204 | duration 1.1s
# Epoch  47 ─ val loss 0.015536 | val MAE 0.067608 | duration 1.1s
# Epoch  48 ─ val loss 0.016555 | val MAE 0.072016 | duration 1.1s
# Epoch  49 ─ val loss 0.015943 | val MAE 0.068128 | duration 1.2s
# Epoch  50 ─ val loss 0.016029 | val MAE 0.068700 | duration 1.1s
# Epoch  51 ─ val loss 0.015623 | val MAE 0.067902 | duration 1.1s
# Epoch  52 ─ val loss 0.016099 | val MAE 0.069477 | duration 1.2s
# Epoch  53 ─ val loss 0.015668 | val MAE 0.068022 | duration 1.1s
# Epoch  54 ─ val loss 0.018093 | val MAE 0.072654 | duration 1.1s
# Epoch  55 ─ val loss 0.015453 | val MAE 0.068315 | duration 1.5s
# Epoch  56 ─ val loss 0.015821 | val MAE 0.067566 | duration 1.3s
# Epoch  57 ─ val loss 0.015621 | val MAE 0.067499 | duration 1.3s
# Epoch  58 ─ val loss 0.015746 | val MAE 0.067775 | duration 1.2s
# Epoch  59 ─ val loss 0.015828 | val MAE 0.068682 | duration 1.2s
# Epoch  60 ─ val loss 0.015548 | val MAE 0.067459 | duration 1.2s
# Epoch  61 ─ val loss 0.015650 | val MAE 0.068183 | duration 1.2s
# Epoch  62 ─ val loss 0.015833 | val MAE 0.069769 | duration 1.2s
# Epoch  63 ─ val loss 0.015576 | val MAE 0.067780 | duration 1.1s
# Epoch  64 ─ val loss 0.015778 | val MAE 0.069292 | duration 1.1s
# Epoch  65 ─ val loss 0.015646 | val MAE 0.067151 | duration 1.1s
# Early stopped after epoch 65
#
# ========== FINAL REPORT ==========
# Val MSE = 0.015646
# Val MAE = 0.067151
# Val R2  = 0.894697

# %%
# # find the index of the best-performing model in the test set
# def find_best_model_index():
#     _, _, val_early = load_dataset(DATASET, metrics_file='metrics_merged_early.csv', load_class_acc=True, stage='early')
#     _, _, val_middle = load_dataset(DATASET, metrics_file='metrics_merged_middle.csv', load_class_acc=True, stage='middle')
#     _, _, val_final = load_dataset(DATASET, metrics_file='metrics_merged_final.csv', load_class_acc=True, stage='final')

#     overall_accuracies_val = np.concatenate([val_early[1][:, 0], val_middle[1][:, 0], val_final[1][:, 0]])

#     best_model_idx = np.argmax(overall_accuracies_val)
#     print(f"Best model index in validation set: {best_model_idx}, mean accuracy: {overall_accuracies_val[best_model_idx]}")
#     return best_model_idx

MODEL_IDX = find_best_model_index(DATASET, partition="test")
# Out:
# dirname:  /Users/moos/Desktop/snijzaal/WeightSpaceClassifier/model_zoo/fashion_mnist
# WARNING:root:Using default seed 123 for shuffling. This results in the canonical train/test/val splits for this project. If a random split is desired, please use a different seed.
# dirname:  /Users/moos/Desktop/snijzaal/WeightSpaceClassifier/model_zoo/fashion_mnist
# WARNING:root:Using default seed 123 for shuffling. This results in the canonical train/test/val splits for this project. If a random split is desired, please use a different seed.
# dirname:  /Users/moos/Desktop/snijzaal/WeightSpaceClassifier/model_zoo/fashion_mnist
# WARNING:root:Using default seed 123 for shuffling. This results in the canonical train/test/val splits for this project. If a random split is desired, please use a different seed.
# Best model index in test set: 18191, accuracy: 0.8853999972343445

# %% [markdown]
# Loss functions

# %%
from jaxtyping import Float, Array

# ----- loss functions -----
simple_loss = lambda pred, target_idx: pred[target_idx]  # minimize the accuracy of the target class

def simple_loss(pred, target_idx):
    return pred[target_idx]  # minimize the accuracy of the target class

def unlearning_and_faithfulness_loss(pred, true, target_idx, beta=1.0):  # needs a better name
    target_term = pred[target_idx]  # we want to minimize this

    # mse = ((true - pred) ** 2).mean()  # we want the regressorlens to remain faithful to the actual performance
    mae = (true - pred).abs().mean()

    # return target_term + mse
    return target_term + beta * mae  # minimize predicted target performance

def boost_loss(pred, target_idx, beta=1.0):
    target_term = pred[target_idx]  # we want to minimize this

    # set target index zero for this term by multiplying with a mask
    mask = torch.ones_like(pred, requires_grad=False)
    mask[target_idx] = 0
    maintain_rest_term = (pred * mask).sum()  # we want to increase or at least maintain the accuracy of the other classes

    return target_term - beta * maintain_rest_term

def unlearning_metric(before_accs, after_accs, target_idx: int):

    target_term: float = -1 * min((after_accs[target_idx] - before_accs[target_idx]), 0)
    
    rest_before_accs = np.delete(before_accs, target_idx)
    rest_after_accs = np.delete(after_accs, target_idx)
    x = np.clip(rest_after_accs - rest_before_accs, a_min=None, a_max=0)
    maintain_rest_term = -1 * np.mean(x)
    return target_term - maintain_rest_term

# %% [markdown]
# unlearning

# %%
from IPython.display import clear_output, display
from matplotlib.pyplot import axes

MODEL_IDX = 18191
assert isinstance(RegressorLens, nn.Module), f"RegressorLens is not an instance of torch.nn.Module but {type(RegressorLens)}"
input_weights: np.ndarray = weights_test[MODEL_IDX]
# inputs_weights: np.ndarray = weights_val[MODEL_IDX]
steps: int = 100
step_size: float = 1
target_class: int = 4
og_config: pd.Series = configs_test.iloc[MODEL_IDX]
# og_config: pd.Series = configs_val.iloc[MODEL_IDX]
beta = 0.1
stop_threshold = 0.6
animate = True

"""
    input_weights: np.ndarray, weights of the model to be unlearned
    steps: int - number of optimization steps
    lens: torch.nn.Module - pretrained regressor lens model
    step_size: float - step size for the optimization
    target_class: int - class index to be unlearned
    og_config - original configuration of the model to be unlearned (for reconstructing the model)
"""

def unlearn():
    print("Starting unlearning procedure")
    diffs_list = []
    loss_list = []
    target_term_list = []
    # mse_term_list = []
    mae_term_list = []
    cosine_sim_list = []
    metric_list = []
    maintain_rest_list = []

    before_accs = test_network_accuracy(input_weights, og_config["config.activation"])[1]

    # convert input weights to tensor for optimization
    doctored_input_weights = torch.tensor(input_weights, requires_grad=True, dtype=torch.float32)
    RegressorLens.eval()

    # optimize only the INPUT weights
    for param in RegressorLens.parameters():
        param.requires_grad = False

    # for i in tqdm(range(steps), desc="Unlearning in progress"):
    for i in range(steps): 

        # this is expensive: a new model needs to be reconstructed and evaluated at every step
        true = torch.tensor(
            test_network_accuracy(doctored_input_weights.detach().numpy(), og_config["config.activation"])[1],
            dtype=torch.float32,
        )

        pred: torch.Tensor = RegressorLens(doctored_input_weights.unsqueeze(0)).squeeze(0)  # forward pass
        loss = boost_loss(pred, target_class, beta=beta)
        loss.backward()  # compute gradients

        gradient = doctored_input_weights.grad.clone() # type: ignore
        if i == 0:
            first_gradient = gradient

        ### ACTUAL OPTIMIZATION STEP ###
        with torch.no_grad():
            doctored_input_weights -= step_size * gradient  # gradient step # type: ignore
            doctored_input_weights.grad.zero_()  # zero gradients # type:  ignore

        # stopping criterion: cosine_similarity between gradient and first gradient should stay below a threshold
        cos_sim = np.dot(gradient, first_gradient) / (np.linalg.norm(gradient) * np.linalg.norm(first_gradient))
        if cos_sim < stop_threshold:
            print(f"Stopping early at step {i} due cosine similarity below threshold ({cos_sim:.4f} < {stop_threshold})")
            break

        # -------- for analysis --------
        target_term: float = pred[target_class].item()
        # mse_term: float = ((true - pred) ** 2).mean().item()
        mae_term: float = (true - pred).abs().mean().item()
        mean_diff = abs((pred.detach().numpy() - np.array(true.detach().numpy()))).mean()
        metric = unlearning_metric(np.array(before_accs), true.detach().numpy(), target_class)
        mask = torch.ones_like(pred, requires_grad=False)
        mask[target_class] = 0
        maintain_rest_term = beta * -1 * (pred * mask).sum().item()

        loss_list.append(loss.item())
        target_term_list.append(target_term)
        # mse_term_list.append(mse_term)
        mae_term_list.append(mae_term)
        diffs_list.append(mean_diff)
        cosine_sim_list.append(cos_sim)
        metric_list.append(metric)
        maintain_rest_list.append(maintain_rest_term)

        if animate:
            # ------- plot -------
            clear_output(wait=True)
            fig, axes = plt.subplots(2, 2, figsize=(18, 12))

            before_accs = accuracies_test[MODEL_IDX]
            # before_accs = accuracies_val[MODEL_IDX]
            assert isinstance(RegressorLens, nn.Module), f"RegressorLens is not an instance of torch.nn.Module but {type(RegressorLens)}"
            preds = RegressorLens(doctored_input_weights.unsqueeze(0)).squeeze().detach().numpy()
            actual_accs = test_network_accuracy(doctored_input_weights.detach().numpy(), og_config["config.activation"])[1]

            classes = np.arange(len(preds))
            bar_width = 0.25
            ax = axes[0, 0]
            ax.bar(classes - bar_width, before_accs, width=bar_width, label="Before unlearning", alpha=0.7)
            ax.bar(classes,              actual_accs, width=bar_width, label="After unlearning", alpha=0.7)
            ax.bar(classes + bar_width,  preds,       width=bar_width, label="Predicted by RegressorLens", alpha=0.7)
            ax.set_xlabel("Class index")
            ax.set_ylabel("Accuracy")
            ax.set_title(f"Step {i}: Class-wise accuracies: Before vs Predicted & Actual")
            ax.set_xticks(classes)
            ax.set_ylim(0, 1)
            ax.grid(axis="y", linestyle="--", alpha=0.7)
            ax.legend()

            # ------- (2,0) unlearning metric -------
            ax = axes[0, 1]
            ax.plot(metric_list)
            ax.set_xlabel("Unlearning step")
            ax.set_ylabel("Unlearning metric")
            ax.set_title("Unlearning metric over unlearning steps")
            ax.set_ylim(-1.05, 1.05)
            ax.grid(linestyle="--", alpha=0.3)

            ax = axes[1, 0]
            ax.plot(diffs_list)
            ax.set_xlabel("Unlearning step")
            ax.set_ylabel("Mean prediction error")
            ax.set_title("Mean prediction error over unlearning steps")
            ax.set_ylim(-0.05, 1.05)
            ax.grid(linestyle="--", alpha=0.3)

            ax = axes[1, 1]
            ax.plot(cosine_sim_list)
            ax.set_xlabel("Unlearning step")
            ax.set_ylabel("Cosine similarity")
            ax.set_title("Cosine similarity with first gradient")
            ax.set_ylim(0, 1.05)
            ax.grid(linestyle="--", alpha=0.3)

            fig.suptitle(f"Unlearning procedure for model index {MODEL_IDX}, target class {target_class}", fontsize=16, fontweight='bold')
            plt.tight_layout(rect=[0, 0, 1, 0.97]) # type: ignore

            display(fig)

            # input("Press Enter to continue to the next step...")

            plt.close(fig)

    return {"loss_list": loss_list,
            "target_term_list": target_term_list,
            # "mse_term_list": mse_term_list,
            "mae_term_list": mae_term_list,
            "diffs_list": diffs_list,
            "cosine_sim_list": cosine_sim_list,
            "metric_list": metric_list,
            "maintain_rest_list": maintain_rest_list
            }

unlearn()
# Out:
# Stopping early at step 13 due cosine similarity below threshold (-0.4186 < 0.6)
# {'loss_list': [-0.027974963188171387,
#   -0.0395430326461792,
#   -0.04719418287277222,
#   -0.05433768033981323,
#   -0.06131476163864136,
#   -0.07044273614883423,
#   -0.08341336250305176,
#   -0.10299980640411377,
#   -0.13123708963394165,
#   -0.1640411615371704,
#   -0.21645903587341309,
#   -0.3611300587654114,
#   -0.6361913084983826],
#  'target_term_list': [0.7565789222717285,
#   0.7444061040878296,
#   0.7361810803413391,
#   0.7284539341926575,
#   0.7209233641624451,
#   0.7111204862594604,
#   0.6974181532859802,
#   0.6767786145210266,
#   0.6473362445831299,
#   0.6132122278213501,
#   0.5589796900749207,
#   0.4072730541229248,
#   0.07612567394971848],
#  'mae_term_list': [0.026834238320589066,
#   0.02763003669679165,
#   0.028024012222886086,
#   0.027296822518110275,
#   0.02816837467253208,
#   0.02728213742375374,
#   0.02642095647752285,
#   0.0251951701939106,
#   0.02805277146399021,
#   0.032505132257938385,
#   0.03743477538228035,
#   0.050264935940504074,
#   0.14264628291130066],
#  'diffs_list': [0.026834238,
#   0.027630037,
#   0.028024012,
#   0.027296823,
#   0.028168375,
#   0.027282137,
#   0.026420956,
#   0.02519517,
#   0.028052771,
#   0.032505132,
#   0.037434775,
#   0.050264936,
#   0.14264627],
#  'cosine_sim_list': [0.99999994,
#   0.9683489,
#   0.96141803,
#   0.9507098,
#   0.9335229,
#   0.9325133,
#   0.9087494,
#   0.9071492,
#   0.90288466,
#   0.87872106,
#   0.79560065,
#   0.7509922,
#   0.73967785],
#  'metric_list': [-7.84132214715072e-09,
#   0.012111114105209708,
#   0.026888887048698962,
#   0.043000015895813704,
#   0.05222222534939647,
#   0.07244448526762426,
#   0.09666666714474559,
#   0.13422223599627614,
#   0.19344448391348124,
#   0.25655555725097656,
#   0.3182222321629524,
#   0.42000001668930054,
#   0.4611111283302307],
#  'maintain_rest_list': [-0.7845538616180421,
#   -0.7839491367340088,
#   -0.7833752632141113,
#   -0.7827916145324707,
#   -0.7822381019592286,
#   -0.7815631866455078,
#   -0.780831527709961,
#   -0.7797783851623535,
#   -0.7785733222961426,
#   -0.7772533893585205,
#   -0.7754387378692628,
#   -0.7684031009674073,
#   -0.7123169898986816]}

# %%
# do it 5 times and report variance in unlearning metric
animate = False
final_unlearning_metrics = []
for i in range(5):
    metrics = unlearn()
    final_unlearning_metrics.append(metrics["metric_list"][-1])

avg_metric = np.mean(final_unlearning_metrics)
std_metric = np.std(final_unlearning_metrics)

print(f"Final unlearning metric over 5 runs: avg={avg_metric:.4f}, std={std_metric:.4f}")
# Out:
# Starting unlearning procedure
# Stopping early at step 13 due cosine similarity below threshold (-0.4186 < 0.6)
# Starting unlearning procedure
# Stopping early at step 13 due cosine similarity below threshold (-0.4186 < 0.6)
# Starting unlearning procedure
# Stopping early at step 13 due cosine similarity below threshold (-0.4186 < 0.6)
# Starting unlearning procedure
# Stopping early at step 13 due cosine similarity below threshold (-0.4186 < 0.6)
# Starting unlearning procedure
# Stopping early at step 13 due cosine similarity below threshold (-0.4186 < 0.6)

# %% [markdown]
# ## 1. Train Metanetwork on this branch (main) and evaluate it here and on the other (old)

# %%
MODEL_IDX = 18191
animate = False
final_unlearning_metrics = []

# pick a random model from the final 1/3rd of the test set 100 times
for i in range(100):
    # MODEL_IDX = np.random.choice(range(len(weights_test) // 3, len(weights_test)))
    MODEL_IDX += 1
    print(f"Unlearning model index {MODEL_IDX} (run {i+1}/100)")
    input_weights: np.ndarray = weights_test[MODEL_IDX]
    og_config: pd.Series = configs_test.iloc[MODEL_IDX]
    metrics = unlearn()
    final_unlearning_metrics.append(metrics["metric_list"][-1])
    print(f"Final unlearning metric for model index {MODEL_IDX}: {metrics['metric_list'][-1]:.4f}\n")
    
avg_metric = np.mean(final_unlearning_metrics)
std_metric = np.std(final_unlearning_metrics)   
print(f"Final unlearning metric over {i+1} runs: avg={avg_metric:.4f}, std={std_metric:.4f}")
# Out:
# Unlearning model index 18192 (run 1/100)
# Starting unlearning procedure
# Stopping early at step 29 due cosine similarity below threshold (-0.5156 < 0.6)
# Final unlearning metric for model index 18192: 0.1056
#
# Unlearning model index 18193 (run 2/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (0.1112 < 0.6)
# Final unlearning metric for model index 18193: -0.0000
#
# Unlearning model index 18194 (run 3/100)
# Starting unlearning procedure
# Stopping early at step 9 due cosine similarity below threshold (0.4869 < 0.6)
# Final unlearning metric for model index 18194: 0.1066
#
# Unlearning model index 18195 (run 4/100)
# Starting unlearning procedure
# Stopping early at step 5 due cosine similarity below threshold (0.5580 < 0.6)
# Final unlearning metric for model index 18195: 0.2974
#
# Unlearning model index 18196 (run 5/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.2952 < 0.6)
# Final unlearning metric for model index 18196: 0.0000
#
# Unlearning model index 18197 (run 6/100)
# Starting unlearning procedure
# Stopping early at step 4 due cosine similarity below threshold (0.5473 < 0.6)
# Final unlearning metric for model index 18197: 0.1600
#
# Unlearning model index 18198 (run 7/100)
# Starting unlearning procedure
# Stopping early at step 29 due cosine similarity below threshold (0.5303 < 0.6)
# Final unlearning metric for model index 18198: 0.4893
#
# Unlearning model index 18199 (run 8/100)
# Starting unlearning procedure
# Stopping early at step 16 due cosine similarity below threshold (0.5886 < 0.6)
# Final unlearning metric for model index 18199: 0.2927
#
# Unlearning model index 18200 (run 9/100)
# Starting unlearning procedure
# Stopping early at step 14 due cosine similarity below threshold (0.5904 < 0.6)
# Final unlearning metric for model index 18200: 0.0942
#
# Unlearning model index 18201 (run 10/100)
# Starting unlearning procedure
# Stopping early at step 4 due cosine similarity below threshold (0.4496 < 0.6)
# Final unlearning metric for model index 18201: -0.1761
#
# Unlearning model index 18202 (run 11/100)
# Starting unlearning procedure
# Stopping early at step 14 due cosine similarity below threshold (0.5753 < 0.6)
# Final unlearning metric for model index 18202: 0.3082
#
# Unlearning model index 18203 (run 12/100)
# Starting unlearning procedure
# Stopping early at step 3 due cosine similarity below threshold (0.4625 < 0.6)
# Final unlearning metric for model index 18203: 0.2282
#
# Unlearning model index 18204 (run 13/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.3536 < 0.6)
# Final unlearning metric for model index 18204: -0.0000
#
# Unlearning model index 18205 (run 14/100)
# Starting unlearning procedure
# Stopping early at step 9 due cosine similarity below threshold (0.5945 < 0.6)
# Final unlearning metric for model index 18205: 0.2747
#
# Unlearning model index 18206 (run 15/100)
# Starting unlearning procedure
# Stopping early at step 18 due cosine similarity below threshold (0.5260 < 0.6)
# Final unlearning metric for model index 18206: 0.0273
#
# Unlearning model index 18207 (run 16/100)
# Starting unlearning procedure
# Stopping early at step 19 due cosine similarity below threshold (0.5591 < 0.6)
# Final unlearning metric for model index 18207: 0.1453
#
# Unlearning model index 18208 (run 17/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.3629 < 0.6)
# Final unlearning metric for model index 18208: 0.0000
#
# Unlearning model index 18209 (run 18/100)
# Starting unlearning procedure
# Final unlearning metric for model index 18209: -0.0172
#
# Unlearning model index 18210 (run 19/100)
# Starting unlearning procedure
# Stopping early at step 10 due cosine similarity below threshold (0.5559 < 0.6)
# Final unlearning metric for model index 18210: 0.6130
#
# Unlearning model index 18211 (run 20/100)
# Starting unlearning procedure
# Stopping early at step 14 due cosine similarity below threshold (0.5926 < 0.6)
# Final unlearning metric for model index 18211: 0.1567
#
# Unlearning model index 18212 (run 21/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (0.0352 < 0.6)
# Final unlearning metric for model index 18212: 0.0000
#
# Unlearning model index 18213 (run 22/100)
# Starting unlearning procedure
# Stopping early at step 22 due cosine similarity below threshold (0.5711 < 0.6)
# Final unlearning metric for model index 18213: 0.0070
#
# Unlearning model index 18214 (run 23/100)
# Starting unlearning procedure
# Stopping early at step 11 due cosine similarity below threshold (0.4296 < 0.6)
# Final unlearning metric for model index 18214: 0.1533
#
# Unlearning model index 18215 (run 24/100)
# Starting unlearning procedure
# Stopping early at step 35 due cosine similarity below threshold (0.5966 < 0.6)
# Final unlearning metric for model index 18215: 0.5459
#
# Unlearning model index 18216 (run 25/100)
# Starting unlearning procedure
# Stopping early at step 14 due cosine similarity below threshold (0.5947 < 0.6)
# Final unlearning metric for model index 18216: 0.3628
#
# Unlearning model index 18217 (run 26/100)
# Starting unlearning procedure
# Stopping early at step 14 due cosine similarity below threshold (0.5338 < 0.6)
# Final unlearning metric for model index 18217: 0.3626
#
# Unlearning model index 18218 (run 27/100)
# Starting unlearning procedure
# Stopping early at step 24 due cosine similarity below threshold (0.5853 < 0.6)
# Final unlearning metric for model index 18218: 0.0960
#
# Unlearning model index 18219 (run 28/100)
# Starting unlearning procedure
# Stopping early at step 5 due cosine similarity below threshold (0.5126 < 0.6)
# Final unlearning metric for model index 18219: 0.2438
#
# Unlearning model index 18220 (run 29/100)
# Starting unlearning procedure
# Stopping early at step 15 due cosine similarity below threshold (0.5083 < 0.6)
# Final unlearning metric for model index 18220: 0.4658
#
# Unlearning model index 18221 (run 30/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.2422 < 0.6)
# Final unlearning metric for model index 18221: 0.0000
#
# Unlearning model index 18222 (run 31/100)
# Starting unlearning procedure
# Stopping early at step 13 due cosine similarity below threshold (0.4875 < 0.6)
# Final unlearning metric for model index 18222: 0.4750
#
# Unlearning model index 18223 (run 32/100)
# Starting unlearning procedure
# Stopping early at step 2 due cosine similarity below threshold (-0.2102 < 0.6)
# Final unlearning metric for model index 18223: 0.4227
#
# Unlearning model index 18224 (run 33/100)
# Starting unlearning procedure
# Stopping early at step 30 due cosine similarity below threshold (0.5840 < 0.6)
# Final unlearning metric for model index 18224: 0.2754
#
# Unlearning model index 18225 (run 34/100)
# Starting unlearning procedure
# Stopping early at step 46 due cosine similarity below threshold (0.5728 < 0.6)
# Final unlearning metric for model index 18225: 0.6547
#
# Unlearning model index 18226 (run 35/100)
# Starting unlearning procedure
# Stopping early at step 4 due cosine similarity below threshold (0.5684 < 0.6)
# Final unlearning metric for model index 18226: 0.0670
#
# Unlearning model index 18227 (run 36/100)
# Starting unlearning procedure
# Stopping early at step 13 due cosine similarity below threshold (0.4712 < 0.6)
# Final unlearning metric for model index 18227: 0.3026
#
# Unlearning model index 18228 (run 37/100)
# Starting unlearning procedure
# Stopping early at step 41 due cosine similarity below threshold (0.5234 < 0.6)
# Final unlearning metric for model index 18228: 0.1766
#
# Unlearning model index 18229 (run 38/100)
# Starting unlearning procedure
# Stopping early at step 22 due cosine similarity below threshold (0.5448 < 0.6)
# Final unlearning metric for model index 18229: 0.4296
#
# Unlearning model index 18230 (run 39/100)
# Starting unlearning procedure
# Stopping early at step 33 due cosine similarity below threshold (0.5057 < 0.6)
# Final unlearning metric for model index 18230: 0.1873
#
# Unlearning model index 18231 (run 40/100)
# Starting unlearning procedure
# Stopping early at step 4 due cosine similarity below threshold (0.4771 < 0.6)
# Final unlearning metric for model index 18231: 0.4228
#
# Unlearning model index 18232 (run 41/100)
# Starting unlearning procedure
# Final unlearning metric for model index 18232: 0.2108
#
# Unlearning model index 18233 (run 42/100)
# Starting unlearning procedure
# Stopping early at step 2 due cosine similarity below threshold (0.5989 < 0.6)
# Final unlearning metric for model index 18233: 0.1311
#
# Unlearning model index 18234 (run 43/100)
# Starting unlearning procedure
# Stopping early at step 5 due cosine similarity below threshold (0.4577 < 0.6)
# Final unlearning metric for model index 18234: -0.0039
#
# Unlearning model index 18235 (run 44/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.4989 < 0.6)
# Final unlearning metric for model index 18235: 0.0000
#
# Unlearning model index 18236 (run 45/100)
# Starting unlearning procedure
# Stopping early at step 4 due cosine similarity below threshold (0.5670 < 0.6)
# Final unlearning metric for model index 18236: 0.1263
#
# Unlearning model index 18237 (run 46/100)
# Starting unlearning procedure
# Stopping early at step 19 due cosine similarity below threshold (0.5431 < 0.6)
# Final unlearning metric for model index 18237: -0.0926
#
# Unlearning model index 18238 (run 47/100)
# Starting unlearning procedure
# Stopping early at step 5 due cosine similarity below threshold (0.4335 < 0.6)
# Final unlearning metric for model index 18238: 0.4113
#
# Unlearning model index 18239 (run 48/100)
# Starting unlearning procedure
# Stopping early at step 30 due cosine similarity below threshold (0.5911 < 0.6)
# Final unlearning metric for model index 18239: 0.1259
#
# Unlearning model index 18240 (run 49/100)
# Starting unlearning procedure
# Stopping early at step 19 due cosine similarity below threshold (0.5275 < 0.6)
# Final unlearning metric for model index 18240: 0.1857
#
# Unlearning model index 18241 (run 50/100)
# Starting unlearning procedure
# Stopping early at step 22 due cosine similarity below threshold (0.5528 < 0.6)
# Final unlearning metric for model index 18241: 0.1663
#
# Unlearning model index 18242 (run 51/100)
# Starting unlearning procedure
# Stopping early at step 5 due cosine similarity below threshold (0.4151 < 0.6)
# Final unlearning metric for model index 18242: 0.0661
#
# Unlearning model index 18243 (run 52/100)
# Starting unlearning procedure
# Stopping early at step 38 due cosine similarity below threshold (0.5842 < 0.6)
# Final unlearning metric for model index 18243: 0.1453
#
# Unlearning model index 18244 (run 53/100)
# Starting unlearning procedure
# Stopping early at step 17 due cosine similarity below threshold (0.5985 < 0.6)
# Final unlearning metric for model index 18244: -0.0322
#
# Unlearning model index 18245 (run 54/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (0.3867 < 0.6)
# Final unlearning metric for model index 18245: -0.0000
#
# Unlearning model index 18246 (run 55/100)
# Starting unlearning procedure
# Stopping early at step 2 due cosine similarity below threshold (0.3855 < 0.6)
# Final unlearning metric for model index 18246: -0.0143
#
# Unlearning model index 18247 (run 56/100)
# Starting unlearning procedure
# Stopping early at step 4 due cosine similarity below threshold (0.4346 < 0.6)
# Final unlearning metric for model index 18247: 0.3897
#
# Unlearning model index 18248 (run 57/100)
# Starting unlearning procedure
# Stopping early at step 2 due cosine similarity below threshold (0.1164 < 0.6)
# Final unlearning metric for model index 18248: 0.2732
#
# Unlearning model index 18249 (run 58/100)
# Starting unlearning procedure
# Stopping early at step 27 due cosine similarity below threshold (0.5915 < 0.6)
# Final unlearning metric for model index 18249: 0.1551
#
# Unlearning model index 18250 (run 59/100)
# Starting unlearning procedure
# Stopping early at step 33 due cosine similarity below threshold (0.5675 < 0.6)
# Final unlearning metric for model index 18250: 0.0194
#
# Unlearning model index 18251 (run 60/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.1902 < 0.6)
# Final unlearning metric for model index 18251: -0.0000
#
# Unlearning model index 18252 (run 61/100)
# Starting unlearning procedure
# Stopping early at step 71 due cosine similarity below threshold (0.5933 < 0.6)
# Final unlearning metric for model index 18252: 0.3788
#
# Unlearning model index 18253 (run 62/100)
# Starting unlearning procedure
# Stopping early at step 3 due cosine similarity below threshold (0.5977 < 0.6)
# Final unlearning metric for model index 18253: 0.1088
#
# Unlearning model index 18254 (run 63/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.1404 < 0.6)
# Final unlearning metric for model index 18254: -0.0000
#
# Unlearning model index 18255 (run 64/100)
# Starting unlearning procedure
# Stopping early at step 3 due cosine similarity below threshold (0.4214 < 0.6)
# Final unlearning metric for model index 18255: 0.0600
#
# Unlearning model index 18256 (run 65/100)
# Starting unlearning procedure
# Stopping early at step 6 due cosine similarity below threshold (0.5870 < 0.6)
# Final unlearning metric for model index 18256: 0.2161
#
# Unlearning model index 18257 (run 66/100)
# Starting unlearning procedure
# Stopping early at step 13 due cosine similarity below threshold (0.5997 < 0.6)
# Final unlearning metric for model index 18257: 0.4360
#
# Unlearning model index 18258 (run 67/100)
# Starting unlearning procedure
# Stopping early at step 12 due cosine similarity below threshold (0.5560 < 0.6)
# Final unlearning metric for model index 18258: 0.4338
#
# Unlearning model index 18259 (run 68/100)
# Starting unlearning procedure
# Stopping early at step 3 due cosine similarity below threshold (0.5816 < 0.6)
# Final unlearning metric for model index 18259: 0.2791
#
# Unlearning model index 18260 (run 69/100)
# Starting unlearning procedure
# Stopping early at step 7 due cosine similarity below threshold (0.5267 < 0.6)
# Final unlearning metric for model index 18260: 0.4497
#
# Unlearning model index 18261 (run 70/100)
# Starting unlearning procedure
# Stopping early at step 4 due cosine similarity below threshold (0.3719 < 0.6)
# Final unlearning metric for model index 18261: 0.2499
#
# Unlearning model index 18262 (run 71/100)
# Starting unlearning procedure
# Stopping early at step 71 due cosine similarity below threshold (0.5963 < 0.6)
# Final unlearning metric for model index 18262: 0.3070
#
# Unlearning model index 18263 (run 72/100)
# Starting unlearning procedure
# Stopping early at step 3 due cosine similarity below threshold (-0.1565 < 0.6)
# Final unlearning metric for model index 18263: 0.3654
#
# Unlearning model index 18264 (run 73/100)
# Starting unlearning procedure
# Stopping early at step 15 due cosine similarity below threshold (-0.0962 < 0.6)
# Final unlearning metric for model index 18264: 0.3194
#
# Unlearning model index 18265 (run 74/100)
# Starting unlearning procedure
# Stopping early at step 2 due cosine similarity below threshold (-0.0921 < 0.6)
# Final unlearning metric for model index 18265: 0.2827
#
# Unlearning model index 18266 (run 75/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.4880 < 0.6)
# Final unlearning metric for model index 18266: -0.0000
#
# Unlearning model index 18267 (run 76/100)
# Starting unlearning procedure
# Stopping early at step 4 due cosine similarity below threshold (0.5060 < 0.6)
# Final unlearning metric for model index 18267: 0.0211
#
# Unlearning model index 18268 (run 77/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (0.4904 < 0.6)
# Final unlearning metric for model index 18268: -0.0000
#
# Unlearning model index 18269 (run 78/100)
# Starting unlearning procedure
# Stopping early at step 2 due cosine similarity below threshold (0.5482 < 0.6)
# Final unlearning metric for model index 18269: 0.1038
#
# Unlearning model index 18270 (run 79/100)
# Starting unlearning procedure
# Stopping early at step 6 due cosine similarity below threshold (0.5754 < 0.6)
# Final unlearning metric for model index 18270: 0.0216
#
# Unlearning model index 18271 (run 80/100)
# Starting unlearning procedure
# Stopping early at step 8 due cosine similarity below threshold (0.4087 < 0.6)
# Final unlearning metric for model index 18271: 0.2868
#
# Unlearning model index 18272 (run 81/100)
# Starting unlearning procedure
# Stopping early at step 2 due cosine similarity below threshold (-0.0337 < 0.6)
# Final unlearning metric for model index 18272: 0.0633
#
# Unlearning model index 18273 (run 82/100)
# Starting unlearning procedure
# Stopping early at step 11 due cosine similarity below threshold (0.5381 < 0.6)
# Final unlearning metric for model index 18273: 0.1209
#
# Unlearning model index 18274 (run 83/100)
# Starting unlearning procedure
# Stopping early at step 2 due cosine similarity below threshold (0.5748 < 0.6)
# Final unlearning metric for model index 18274: -0.1834
#
# Unlearning model index 18275 (run 84/100)
# Starting unlearning procedure
# Stopping early at step 10 due cosine similarity below threshold (0.4852 < 0.6)
# Final unlearning metric for model index 18275: 0.2371
#
# Unlearning model index 18276 (run 85/100)
# Starting unlearning procedure
# Stopping early at step 22 due cosine similarity below threshold (0.5836 < 0.6)
# Final unlearning metric for model index 18276: 0.2950
#
# Unlearning model index 18277 (run 86/100)
# Starting unlearning procedure
# Stopping early at step 6 due cosine similarity below threshold (0.5634 < 0.6)
# Final unlearning metric for model index 18277: 0.1099
#
# Unlearning model index 18278 (run 87/100)
# Starting unlearning procedure
# Stopping early at step 13 due cosine similarity below threshold (0.5988 < 0.6)
# Final unlearning metric for model index 18278: 0.2461
#
# Unlearning model index 18279 (run 88/100)
# Starting unlearning procedure
# Stopping early at step 7 due cosine similarity below threshold (0.5172 < 0.6)
# Final unlearning metric for model index 18279: 0.1722
#
# Unlearning model index 18280 (run 89/100)
# Starting unlearning procedure
# Stopping early at step 13 due cosine similarity below threshold (0.5871 < 0.6)
# Final unlearning metric for model index 18280: 0.2599
#
# Unlearning model index 18281 (run 90/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (0.1507 < 0.6)
# Final unlearning metric for model index 18281: 0.0000
#
# Unlearning model index 18282 (run 91/100)
# Starting unlearning procedure
# Stopping early at step 18 due cosine similarity below threshold (0.4454 < 0.6)
# Final unlearning metric for model index 18282: -0.0079
#
# Unlearning model index 18283 (run 92/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (0.1007 < 0.6)
# Final unlearning metric for model index 18283: -0.0000
#
# Unlearning model index 18284 (run 93/100)
# Starting unlearning procedure
# Stopping early at step 3 due cosine similarity below threshold (0.3736 < 0.6)
# Final unlearning metric for model index 18284: 0.3424
#
# Unlearning model index 18285 (run 94/100)
# Starting unlearning procedure
# Stopping early at step 2 due cosine similarity below threshold (0.5435 < 0.6)
# Final unlearning metric for model index 18285: -0.0309
#
# Unlearning model index 18286 (run 95/100)
# Starting unlearning procedure
# Stopping early at step 79 due cosine similarity below threshold (0.5406 < 0.6)
# Final unlearning metric for model index 18286: 0.5442
#
# Unlearning model index 18287 (run 96/100)
# Starting unlearning procedure
# Stopping early at step 14 due cosine similarity below threshold (0.4876 < 0.6)
# Final unlearning metric for model index 18287: 0.4897
#
# Unlearning model index 18288 (run 97/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.5230 < 0.6)
# Final unlearning metric for model index 18288: 0.0000
#
# Unlearning model index 18289 (run 98/100)
# Starting unlearning procedure
# Stopping early at step 9 due cosine similarity below threshold (0.5579 < 0.6)
# Final unlearning metric for model index 18289: 0.0660
#
# Unlearning model index 18290 (run 99/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (0.1102 < 0.6)
# Final unlearning metric for model index 18290: 0.0000
#
# Unlearning model index 18291 (run 100/100)
# Starting unlearning procedure
# Stopping early at step 56 due cosine similarity below threshold (0.5777 < 0.6)
# Final unlearning metric for model index 18291: -0.0909
#
# Final unlearning metric over 100 runs: avg=0.1797, std=0.1815

# %%
import math
print(f"Number of runs resulting in positive unlearning metric: {sum(1 for m in final_unlearning_metrics if m.round(4) > 0)} out of {len(final_unlearning_metrics)}")
print(f"Number of runs resulting in negative unlearning metric: {sum(1 for m in final_unlearning_metrics if m.round(4) < 0)} out of {len(final_unlearning_metrics)}")
print(f"Number of runs resulting in zero unlearning metric: {sum(1 for m in final_unlearning_metrics if math.isclose(m.round(4), 0))} out of {len(final_unlearning_metrics)}")
# Out:
# Number of runs resulting in positive unlearning metric: 74 out of 100
# Number of runs resulting in negative unlearning metric: 10 out of 100
# Number of runs resulting in zero unlearning metric: 16 out of 100

# %% [markdown]
# ## 2. Train Metanetwork on the other branch (old) and evaluate it here (main) and on the other (old)

# %%
# RegressorLens = get_regressor_lens(weights_train, accuracies_train, weights_val, accuracies_val, device='cpu')
RegressorLens.load_state_dict(torch.load(f'old_regressor_lens_{DATASET}.pt'))
# Out:
# <All keys matched successfully>

# %%
MODEL_IDX = 18191
animate = False
final_unlearning_metrics = []
# pick a random model from the final 1/3rd of the test set 100 times
for i in range(100):
    # MODEL_IDX = np.random.choice(range(len(weights_test) // 3, len(weights_test)))
    MODEL_IDX += 1
    print(f"Unlearning model index {MODEL_IDX} (run {i+1}/100)")
    input_weights: np.ndarray = weights_test[MODEL_IDX]
    og_config: pd.Series = configs_test.iloc[MODEL_IDX]
    metrics = unlearn()
    final_unlearning_metrics.append(metrics["metric_list"][-1])
    print(f"Final unlearning metric for model index {MODEL_IDX}: {metrics['metric_list'][-1]:.4f}\n")
avg_metric = np.mean(final_unlearning_metrics)
std_metric = np.std(final_unlearning_metrics)   
print(f"Final unlearning metric over {i+1} runs: avg={avg_metric:.4f}, std={std_metric:.4f}")

import math
print(f"Number of runs resulting in positive unlearning metric: {sum(1 for m in final_unlearning_metrics if m.round(4) > 0)} out of {len(final_unlearning_metrics)}")
print(f"Number of runs resulting in negative unlearning metric: {sum(1 for m in final_unlearning_metrics if m.round(4) < 0)} out of {len(final_unlearning_metrics)}")
print(f"Number of runs resulting in zero unlearning metric: {sum(1 for m in final_unlearning_metrics if math.isclose(m.round(4), 0))} out of {len(final_unlearning_metrics)}")
# Out:
# Unlearning model index 18192 (run 1/100)
# Starting unlearning procedure
# Stopping early at step 38 due cosine similarity below threshold (0.5526 < 0.6)
# Final unlearning metric for model index 18192: 0.3602
#
# Unlearning model index 18193 (run 2/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (0.1368 < 0.6)
# Final unlearning metric for model index 18193: -0.0000
#
# Unlearning model index 18194 (run 3/100)
# Starting unlearning procedure
# Stopping early at step 6 due cosine similarity below threshold (0.5913 < 0.6)
# Final unlearning metric for model index 18194: 0.1851
#
# Unlearning model index 18195 (run 4/100)
# Starting unlearning procedure
# Stopping early at step 4 due cosine similarity below threshold (0.4680 < 0.6)
# Final unlearning metric for model index 18195: 0.3384
#
# Unlearning model index 18196 (run 5/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.3853 < 0.6)
# Final unlearning metric for model index 18196: 0.0000
#
# Unlearning model index 18197 (run 6/100)
# Starting unlearning procedure
# Stopping early at step 3 due cosine similarity below threshold (0.5970 < 0.6)
# Final unlearning metric for model index 18197: 0.2170
#
# Unlearning model index 18198 (run 7/100)
# Starting unlearning procedure
# Stopping early at step 21 due cosine similarity below threshold (0.5899 < 0.6)
# Final unlearning metric for model index 18198: 0.4328
#
# Unlearning model index 18199 (run 8/100)
# Starting unlearning procedure
# Stopping early at step 31 due cosine similarity below threshold (0.5913 < 0.6)
# Final unlearning metric for model index 18199: 0.2410
#
# Unlearning model index 18200 (run 9/100)
# Starting unlearning procedure
# Stopping early at step 15 due cosine similarity below threshold (0.5879 < 0.6)
# Final unlearning metric for model index 18200: 0.0410
#
# Unlearning model index 18201 (run 10/100)
# Starting unlearning procedure
# Stopping early at step 15 due cosine similarity below threshold (0.5999 < 0.6)
# Final unlearning metric for model index 18201: 0.1867
#
# Unlearning model index 18202 (run 11/100)
# Starting unlearning procedure
# Stopping early at step 9 due cosine similarity below threshold (0.5855 < 0.6)
# Final unlearning metric for model index 18202: 0.0828
#
# Unlearning model index 18203 (run 12/100)
# Starting unlearning procedure
# Stopping early at step 2 due cosine similarity below threshold (0.5964 < 0.6)
# Final unlearning metric for model index 18203: 0.0904
#
# Unlearning model index 18204 (run 13/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.0420 < 0.6)
# Final unlearning metric for model index 18204: -0.0000
#
# Unlearning model index 18205 (run 14/100)
# Starting unlearning procedure
# Stopping early at step 51 due cosine similarity below threshold (0.5889 < 0.6)
# Final unlearning metric for model index 18205: 0.2539
#
# Unlearning model index 18206 (run 15/100)
# Starting unlearning procedure
# Stopping early at step 30 due cosine similarity below threshold (0.5687 < 0.6)
# Final unlearning metric for model index 18206: 0.2423
#
# Unlearning model index 18207 (run 16/100)
# Starting unlearning procedure
# Stopping early at step 12 due cosine similarity below threshold (0.5430 < 0.6)
# Final unlearning metric for model index 18207: 0.2130
#
# Unlearning model index 18208 (run 17/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.1728 < 0.6)
# Final unlearning metric for model index 18208: 0.0000
#
# Unlearning model index 18209 (run 18/100)
# Starting unlearning procedure
# Stopping early at step 50 due cosine similarity below threshold (0.5867 < 0.6)
# Final unlearning metric for model index 18209: 0.0333
#
# Unlearning model index 18210 (run 19/100)
# Starting unlearning procedure
# Stopping early at step 43 due cosine similarity below threshold (0.5943 < 0.6)
# Final unlearning metric for model index 18210: 0.5940
#
# Unlearning model index 18211 (run 20/100)
# Starting unlearning procedure
# Stopping early at step 17 due cosine similarity below threshold (0.5860 < 0.6)
# Final unlearning metric for model index 18211: 0.1271
#
# Unlearning model index 18212 (run 21/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.3010 < 0.6)
# Final unlearning metric for model index 18212: 0.0000
#
# Unlearning model index 18213 (run 22/100)
# Starting unlearning procedure
# Stopping early at step 12 due cosine similarity below threshold (0.1527 < 0.6)
# Final unlearning metric for model index 18213: 0.0944
#
# Unlearning model index 18214 (run 23/100)
# Starting unlearning procedure
# Stopping early at step 10 due cosine similarity below threshold (0.5889 < 0.6)
# Final unlearning metric for model index 18214: 0.5340
#
# Unlearning model index 18215 (run 24/100)
# Starting unlearning procedure
# Stopping early at step 29 due cosine similarity below threshold (0.5734 < 0.6)
# Final unlearning metric for model index 18215: 0.6291
#
# Unlearning model index 18216 (run 25/100)
# Starting unlearning procedure
# Stopping early at step 7 due cosine similarity below threshold (0.5027 < 0.6)
# Final unlearning metric for model index 18216: 0.2296
#
# Unlearning model index 18217 (run 26/100)
# Starting unlearning procedure
# Stopping early at step 13 due cosine similarity below threshold (0.5204 < 0.6)
# Final unlearning metric for model index 18217: 0.1660
#
# Unlearning model index 18218 (run 27/100)
# Starting unlearning procedure
# Stopping early at step 6 due cosine similarity below threshold (0.5816 < 0.6)
# Final unlearning metric for model index 18218: 0.1736
#
# Unlearning model index 18219 (run 28/100)
# Starting unlearning procedure
# Stopping early at step 5 due cosine similarity below threshold (0.4615 < 0.6)
# Final unlearning metric for model index 18219: 0.2922
#
# Unlearning model index 18220 (run 29/100)
# Starting unlearning procedure
# Stopping early at step 22 due cosine similarity below threshold (0.5790 < 0.6)
# Final unlearning metric for model index 18220: 0.2647
#
# Unlearning model index 18221 (run 30/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (0.0051 < 0.6)
# Final unlearning metric for model index 18221: 0.0000
#
# Unlearning model index 18222 (run 31/100)
# Starting unlearning procedure
# Stopping early at step 31 due cosine similarity below threshold (0.5998 < 0.6)
# Final unlearning metric for model index 18222: 0.4236
#
# Unlearning model index 18223 (run 32/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.2902 < 0.6)
# Final unlearning metric for model index 18223: 0.0000
#
# Unlearning model index 18224 (run 33/100)
# Starting unlearning procedure
# Stopping early at step 44 due cosine similarity below threshold (0.5767 < 0.6)
# Final unlearning metric for model index 18224: 0.3239
#
# Unlearning model index 18225 (run 34/100)
# Starting unlearning procedure
# Stopping early at step 21 due cosine similarity below threshold (0.5121 < 0.6)
# Final unlearning metric for model index 18225: 0.3331
#
# Unlearning model index 18226 (run 35/100)
# Starting unlearning procedure
# Stopping early at step 2 due cosine similarity below threshold (0.5907 < 0.6)
# Final unlearning metric for model index 18226: 0.0393
#
# Unlearning model index 18227 (run 36/100)
# Starting unlearning procedure
# Stopping early at step 6 due cosine similarity below threshold (0.5898 < 0.6)
# Final unlearning metric for model index 18227: 0.2727
#
# Unlearning model index 18228 (run 37/100)
# Starting unlearning procedure
# Stopping early at step 29 due cosine similarity below threshold (0.5787 < 0.6)
# Final unlearning metric for model index 18228: 0.2610
#
# Unlearning model index 18229 (run 38/100)
# Starting unlearning procedure
# Stopping early at step 26 due cosine similarity below threshold (0.5995 < 0.6)
# Final unlearning metric for model index 18229: 0.3241
#
# Unlearning model index 18230 (run 39/100)
# Starting unlearning procedure
# Stopping early at step 34 due cosine similarity below threshold (0.5952 < 0.6)
# Final unlearning metric for model index 18230: 0.2791
#
# Unlearning model index 18231 (run 40/100)
# Starting unlearning procedure
# Stopping early at step 5 due cosine similarity below threshold (0.5670 < 0.6)
# Final unlearning metric for model index 18231: 0.2434
#
# Unlearning model index 18232 (run 41/100)
# Starting unlearning procedure
# Final unlearning metric for model index 18232: 0.2132
#
# Unlearning model index 18233 (run 42/100)
# Starting unlearning procedure
# Stopping early at step 2 due cosine similarity below threshold (0.4994 < 0.6)
# Final unlearning metric for model index 18233: 0.1027
#
# Unlearning model index 18234 (run 43/100)
# Starting unlearning procedure
# Stopping early at step 3 due cosine similarity below threshold (0.5667 < 0.6)
# Final unlearning metric for model index 18234: -0.0248
#
# Unlearning model index 18235 (run 44/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.1619 < 0.6)
# Final unlearning metric for model index 18235: 0.0000
#
# Unlearning model index 18236 (run 45/100)
# Starting unlearning procedure
# Stopping early at step 6 due cosine similarity below threshold (0.5654 < 0.6)
# Final unlearning metric for model index 18236: 0.0746
#
# Unlearning model index 18237 (run 46/100)
# Starting unlearning procedure
# Stopping early at step 18 due cosine similarity below threshold (0.5928 < 0.6)
# Final unlearning metric for model index 18237: -0.1776
#
# Unlearning model index 18238 (run 47/100)
# Starting unlearning procedure
# Stopping early at step 6 due cosine similarity below threshold (0.5824 < 0.6)
# Final unlearning metric for model index 18238: 0.3282
#
# Unlearning model index 18239 (run 48/100)
# Starting unlearning procedure
# Stopping early at step 33 due cosine similarity below threshold (0.5691 < 0.6)
# Final unlearning metric for model index 18239: 0.3511
#
# Unlearning model index 18240 (run 49/100)
# Starting unlearning procedure
# Stopping early at step 16 due cosine similarity below threshold (0.5884 < 0.6)
# Final unlearning metric for model index 18240: 0.1261
#
# Unlearning model index 18241 (run 50/100)
# Starting unlearning procedure
# Stopping early at step 36 due cosine similarity below threshold (0.5727 < 0.6)
# Final unlearning metric for model index 18241: 0.5092
#
# Unlearning model index 18242 (run 51/100)
# Starting unlearning procedure
# Stopping early at step 5 due cosine similarity below threshold (0.5448 < 0.6)
# Final unlearning metric for model index 18242: 0.0970
#
# Unlearning model index 18243 (run 52/100)
# Starting unlearning procedure
# Stopping early at step 36 due cosine similarity below threshold (0.5890 < 0.6)
# Final unlearning metric for model index 18243: 0.1861
#
# Unlearning model index 18244 (run 53/100)
# Starting unlearning procedure
# Stopping early at step 10 due cosine similarity below threshold (0.5746 < 0.6)
# Final unlearning metric for model index 18244: -0.0014
#
# Unlearning model index 18245 (run 54/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (0.4600 < 0.6)
# Final unlearning metric for model index 18245: -0.0000
#
# Unlearning model index 18246 (run 55/100)
# Starting unlearning procedure
# Stopping early at step 2 due cosine similarity below threshold (-0.3500 < 0.6)
# Final unlearning metric for model index 18246: 0.1268
#
# Unlearning model index 18247 (run 56/100)
# Starting unlearning procedure
# Stopping early at step 5 due cosine similarity below threshold (0.3137 < 0.6)
# Final unlearning metric for model index 18247: 0.3476
#
# Unlearning model index 18248 (run 57/100)
# Starting unlearning procedure
# Stopping early at step 4 due cosine similarity below threshold (0.4874 < 0.6)
# Final unlearning metric for model index 18248: 0.2524
#
# Unlearning model index 18249 (run 58/100)
# Starting unlearning procedure
# Stopping early at step 12 due cosine similarity below threshold (0.5832 < 0.6)
# Final unlearning metric for model index 18249: 0.1296
#
# Unlearning model index 18250 (run 59/100)
# Starting unlearning procedure
# Stopping early at step 56 due cosine similarity below threshold (0.5994 < 0.6)
# Final unlearning metric for model index 18250: 0.1524
#
# Unlearning model index 18251 (run 60/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.1217 < 0.6)
# Final unlearning metric for model index 18251: -0.0000
#
# Unlearning model index 18252 (run 61/100)
# Starting unlearning procedure
# Final unlearning metric for model index 18252: 0.4612
#
# Unlearning model index 18253 (run 62/100)
# Starting unlearning procedure
# Stopping early at step 4 due cosine similarity below threshold (0.5617 < 0.6)
# Final unlearning metric for model index 18253: 0.0824
#
# Unlearning model index 18254 (run 63/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (0.1389 < 0.6)
# Final unlearning metric for model index 18254: -0.0000
#
# Unlearning model index 18255 (run 64/100)
# Starting unlearning procedure
# Stopping early at step 3 due cosine similarity below threshold (0.4839 < 0.6)
# Final unlearning metric for model index 18255: 0.0934
#
# Unlearning model index 18256 (run 65/100)
# Starting unlearning procedure
# Stopping early at step 7 due cosine similarity below threshold (0.5212 < 0.6)
# Final unlearning metric for model index 18256: 0.3003
#
# Unlearning model index 18257 (run 66/100)
# Starting unlearning procedure
# Stopping early at step 13 due cosine similarity below threshold (0.5602 < 0.6)
# Final unlearning metric for model index 18257: 0.2753
#
# Unlearning model index 18258 (run 67/100)
# Starting unlearning procedure
# Stopping early at step 20 due cosine similarity below threshold (0.5932 < 0.6)
# Final unlearning metric for model index 18258: 0.1644
#
# Unlearning model index 18259 (run 68/100)
# Starting unlearning procedure
# Stopping early at step 2 due cosine similarity below threshold (0.5162 < 0.6)
# Final unlearning metric for model index 18259: 0.1567
#
# Unlearning model index 18260 (run 69/100)
# Starting unlearning procedure
# Stopping early at step 10 due cosine similarity below threshold (0.4975 < 0.6)
# Final unlearning metric for model index 18260: 0.3738
#
# Unlearning model index 18261 (run 70/100)
# Starting unlearning procedure
# Stopping early at step 5 due cosine similarity below threshold (0.5458 < 0.6)
# Final unlearning metric for model index 18261: 0.4073
#
# Unlearning model index 18262 (run 71/100)
# Starting unlearning procedure
# Stopping early at step 53 due cosine similarity below threshold (0.5996 < 0.6)
# Final unlearning metric for model index 18262: 0.6190
#
# Unlearning model index 18263 (run 72/100)
# Starting unlearning procedure
# Stopping early at step 4 due cosine similarity below threshold (0.5481 < 0.6)
# Final unlearning metric for model index 18263: 0.4748
#
# Unlearning model index 18264 (run 73/100)
# Starting unlearning procedure
# Stopping early at step 19 due cosine similarity below threshold (0.4701 < 0.6)
# Final unlearning metric for model index 18264: 0.2140
#
# Unlearning model index 18265 (run 74/100)
# Starting unlearning procedure
# Stopping early at step 8 due cosine similarity below threshold (0.5531 < 0.6)
# Final unlearning metric for model index 18265: 0.0869
#
# Unlearning model index 18266 (run 75/100)
# Starting unlearning procedure
# Stopping early at step 2 due cosine similarity below threshold (0.3558 < 0.6)
# Final unlearning metric for model index 18266: 0.4520
#
# Unlearning model index 18267 (run 76/100)
# Starting unlearning procedure
# Stopping early at step 6 due cosine similarity below threshold (0.5014 < 0.6)
# Final unlearning metric for model index 18267: 0.0303
#
# Unlearning model index 18268 (run 77/100)
# Starting unlearning procedure
# Stopping early at step 10 due cosine similarity below threshold (0.5994 < 0.6)
# Final unlearning metric for model index 18268: -0.0228
#
# Unlearning model index 18269 (run 78/100)
# Starting unlearning procedure
# Stopping early at step 2 due cosine similarity below threshold (0.5373 < 0.6)
# Final unlearning metric for model index 18269: 0.2449
#
# Unlearning model index 18270 (run 79/100)
# Starting unlearning procedure
# Stopping early at step 4 due cosine similarity below threshold (0.5041 < 0.6)
# Final unlearning metric for model index 18270: 0.0694
#
# Unlearning model index 18271 (run 80/100)
# Starting unlearning procedure
# Stopping early at step 3 due cosine similarity below threshold (0.5959 < 0.6)
# Final unlearning metric for model index 18271: 0.3196
#
# Unlearning model index 18272 (run 81/100)
# Starting unlearning procedure
# Stopping early at step 3 due cosine similarity below threshold (-0.0008 < 0.6)
# Final unlearning metric for model index 18272: 0.1153
#
# Unlearning model index 18273 (run 82/100)
# Starting unlearning procedure
# Stopping early at step 9 due cosine similarity below threshold (0.5981 < 0.6)
# Final unlearning metric for model index 18273: 0.1130
#
# Unlearning model index 18274 (run 83/100)
# Starting unlearning procedure
# Stopping early at step 3 due cosine similarity below threshold (0.5196 < 0.6)
# Final unlearning metric for model index 18274: -0.0866
#
# Unlearning model index 18275 (run 84/100)
# Starting unlearning procedure
# Stopping early at step 8 due cosine similarity below threshold (0.5375 < 0.6)
# Final unlearning metric for model index 18275: 0.2246
#
# Unlearning model index 18276 (run 85/100)
# Starting unlearning procedure
# Stopping early at step 43 due cosine similarity below threshold (0.5865 < 0.6)
# Final unlearning metric for model index 18276: 0.3518
#
# Unlearning model index 18277 (run 86/100)
# Starting unlearning procedure
# Stopping early at step 6 due cosine similarity below threshold (0.4907 < 0.6)
# Final unlearning metric for model index 18277: 0.1859
#
# Unlearning model index 18278 (run 87/100)
# Starting unlearning procedure
# Stopping early at step 18 due cosine similarity below threshold (0.5548 < 0.6)
# Final unlearning metric for model index 18278: 0.2728
#
# Unlearning model index 18279 (run 88/100)
# Starting unlearning procedure
# Stopping early at step 5 due cosine similarity below threshold (0.5673 < 0.6)
# Final unlearning metric for model index 18279: 0.2160
#
# Unlearning model index 18280 (run 89/100)
# Starting unlearning procedure
# Stopping early at step 12 due cosine similarity below threshold (0.5973 < 0.6)
# Final unlearning metric for model index 18280: 0.1849
#
# Unlearning model index 18281 (run 90/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.1292 < 0.6)
# Final unlearning metric for model index 18281: 0.0000
#
# Unlearning model index 18282 (run 91/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (0.1740 < 0.6)
# Final unlearning metric for model index 18282: -0.0000
#
# Unlearning model index 18283 (run 92/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.1735 < 0.6)
# Final unlearning metric for model index 18283: -0.0000
#
# Unlearning model index 18284 (run 93/100)
# Starting unlearning procedure
# Stopping early at step 3 due cosine similarity below threshold (0.4289 < 0.6)
# Final unlearning metric for model index 18284: 0.5064
#
# Unlearning model index 18285 (run 94/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.0604 < 0.6)
# Final unlearning metric for model index 18285: -0.0000
#
# Unlearning model index 18286 (run 95/100)
# Starting unlearning procedure
# Stopping early at step 72 due cosine similarity below threshold (0.5860 < 0.6)
# Final unlearning metric for model index 18286: -0.0162
#
# Unlearning model index 18287 (run 96/100)
# Starting unlearning procedure
# Stopping early at step 27 due cosine similarity below threshold (0.5927 < 0.6)
# Final unlearning metric for model index 18287: 0.3190
#
# Unlearning model index 18288 (run 97/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (-0.1814 < 0.6)
# Final unlearning metric for model index 18288: 0.0000
#
# Unlearning model index 18289 (run 98/100)
# Starting unlearning procedure
# Stopping early at step 7 due cosine similarity below threshold (0.5931 < 0.6)
# Final unlearning metric for model index 18289: 0.0621
#
# Unlearning model index 18290 (run 99/100)
# Starting unlearning procedure
# Stopping early at step 1 due cosine similarity below threshold (0.1595 < 0.6)
# Final unlearning metric for model index 18290: 0.0000
#
# Unlearning model index 18291 (run 100/100)
# Starting unlearning procedure
# Stopping early at step 73 due cosine similarity below threshold (0.5838 < 0.6)
# Final unlearning metric for model index 18291: -0.0858
#
# Final unlearning metric over 100 runs: avg=0.1848, std=0.1709
# Number of runs resulting in positive unlearning metric: 76 out of 100
# Number of runs resulting in negative unlearning metric: 7 out of 100
# Number of runs resulting in zero unlearning metric: 17 out of 100

# %% [markdown]
# # OTHER SHIT

# %%
fig, axes = plt.subplots(3, 2, figsize=(16, 10))
fig.suptitle(F"UNLEARNING CLASS {target_class}")

# ------- (0,0) loss plotting -------
ax = axes[0, 0]
ax.plot(loss_list, label="Total loss")
ax.plot(target_term_list, label="Target class penalty term")
ax.plot(maintain_rest_list, label="Maintain rest term")
# ax.plot(mse_term_list, label="MSE (RegressorLens faithfulness) term")
# ax.plot(mae_term_list, label="MAE (RegressorLens faithfulness) term")
ax.set_xlabel("Unlearning step")
ax.set_ylabel("Loss")
ax.set_title("Loss over unlearning steps")
# ax.set_ylim(min(loss_list) * 1.2, max(loss_list) * 1.2)
ax.legend()

# ------- (0,1) accuracy -------
before_accs = accuracies_val[MODEL_IDX]
assert isinstance(RegressorLens, nn.Module), f"RegressorLens is not an instance of torch.nn.Module but {type(RegressorLens)}"
preds = RegressorLens(doctored_input_weights.unsqueeze(0)).squeeze().detach().numpy()
actual_accs = test_network_accuracy(doctored_input_weights.detach().numpy(), configs_val.iloc[MODEL_IDX]["config.activation"])[1]

ax = axes[0, 1]
classes = np.arange(len(preds))
bar_width = 0.25
ax.bar(classes - bar_width, before_accs, width=bar_width, label="Before unlearning", alpha=0.7)
ax.bar(classes,              actual_accs, width=bar_width, label="After unlearning", alpha=0.7)
ax.bar(classes + bar_width,  preds,       width=bar_width, label="Predicted by RegressorLens", alpha=0.7)
ax.set_xlabel("Class index")
ax.set_ylabel("Accuracy")
ax.set_title("Class-wise accuracies: Before vs Predicted & Actual")
ax.set_xticks(classes)
ax.set_ylim(0, 1)
ax.grid(axis="y", linestyle="--", alpha=0.7)
ax.legend()

# ------- (1,0) mean prediction error -------
ax = axes[1, 0]
ax.plot(diffs_list)
ax.set_xlabel("Unlearning step")
ax.set_ylabel("Mean prediction error")
ax.set_title("Mean prediction error over unlearning steps")
ax.set_ylim(0, max(diffs_list) * 1.2 if len(diffs_list) else 1)
ax.grid(linestyle="--", alpha=0.3)

# ------- (1,1) gradient cosine similarity -------
ax = axes[1, 1]
ax.plot(cosine_sim_list)
ax.set_xlabel("Unlearning step")
ax.set_ylabel("Cosine similarity")
ax.set_title("Cosine similarity with first gradient")
ax.set_ylim(0, 1)
ax.grid(linestyle="--", alpha=0.3)

# ------- (2,0) unlearning metric -------
ax = axes[2, 0]
ax.plot(metric_list)
ax.set_xlabel("Unlearning step")
ax.set_ylabel("Unlearning metric")
ax.set_title("Unlearning metric over unlearning steps")
ax.set_ylim(min(metric_list) * 1.2, max(metric_list) * 1.2)
ax.grid(linestyle="--", alpha=0.3)

# hide the (2,1) subplot (bottom right)
axes[2, 1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## testing more models

# %%
assert isinstance(RegressorLens, nn.Module), f"RegressorLens is not an instance of torch.nn.Module but {type(RegressorLens)}"
good_models_start_idx = round(len(weights_val) * (2/3))
n_models_to_test = 10
model_idxs = np.random.randint(good_models_start_idx, len(weights_val), size=n_models_to_test)
steps: int = 100
step_size: float = 1
target_class: int = 4
beta = 0.1
stop_threshold = 0.6

diffs_all = []
loss_all = []
target_term_all = []
mae_term_all = []
cosine_sim_all = []
metric_all = []
maintain_rest_all = []
before_accs_all = []
actual_accs_all = []

# for MODEL_IDX in model_idxs:
MODEL_IDX = 16385
for i in tqdm(range(n_models_to_test)):

    input_weights: np.ndarray = weights_val[MODEL_IDX]
    og_config: pd.Series = configs_val.iloc[MODEL_IDX]

    print("Starting unlearning procedure")
    diffs_list = []
    loss_list = []
    target_term_list = []
    # mse_term_list = []
    mae_term_list = []
    cosine_sim_list = []
    metric_list = []
    maintain_rest_list = []

    before_accs = test_network_accuracy(input_weights, og_config["config.activation"])[1]

    # convert input weights to tensor for optimization
    doctored_input_weights = torch.tensor(input_weights, requires_grad=True, dtype=torch.float32)
    RegressorLens.eval()

    # optimize only the INPUT weights
    for param in RegressorLens.parameters():
        param.requires_grad = False

    for i in tqdm(range(steps), desc="Unlearning in progress"):
        
        # this is expensive: a new model needs to be reconstructed and evaluated at every step
        true = torch.tensor(
            test_network_accuracy(doctored_input_weights.detach().numpy(), og_config["config.activation"])[1],
            dtype=torch.float32,
        )

        pred: torch.Tensor = RegressorLens(doctored_input_weights.unsqueeze(0)).squeeze(0)  # forward pass
        loss = boost_loss(pred, target_class, beta=beta)
        loss.backward()  # compute gradients

        gradient = doctored_input_weights.grad.clone()
        if i == 0:
            first_gradient = gradient

        ### ACTUAL OPTIMIZATION STEP ###
        with torch.no_grad():
            doctored_input_weights -= step_size * gradient  # gradient step # type: ignore
            doctored_input_weights.grad.zero_()  # zero gradients # type:  ignore

            # stopping criterion: cosine_similarity between gradient and first gradient should stay below a threshold
        cos_sim = np.dot(gradient, first_gradient) / (np.linalg.norm(gradient) * np.linalg.norm(first_gradient))
        if cos_sim < stop_threshold:
            print(f"Stopping early at step {i} due cosine similarity below threshold ({cos_sim:.4f} < {stop_threshold})")
            break

        # -------- for analysis --------
        target_term: float = pred[target_class].item()
        # mse_term: float = ((true - pred) ** 2).mean().item()
        mae_term: float = (true - pred).abs().mean().item()
        mean_diff = abs((pred.detach().numpy() - np.array(true.detach().numpy()))).mean()
        metric = unlearning_metric(np.array(before_accs), true.detach().numpy(), target_class)
        mask = torch.ones_like(pred, requires_grad=False)
        mask[target_class] = 0
        maintain_rest_term = beta * -1 * (pred * mask).sum().item()

        loss_list.append(loss.item())
        target_term_list.append(target_term)
        # mse_term_list.append(mse_term)
        mae_term_list.append(mae_term)
        diffs_list.append(mean_diff)
        cosine_sim_list.append(cos_sim)
        metric_list.append(metric)
        maintain_rest_list.append(maintain_rest_term)

    diffs_all.append(diffs_list)
    loss_all.append(loss_list)
    target_term_all.append(target_term_list)
    mae_term_all.append(mae_term_list)
    cosine_sim_all.append(cosine_sim_list)
    metric_all.append(metric_list)
    maintain_rest_all.append(maintain_rest_list)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Starting unlearning procedure
# Unlearning in progress:   6%|▌         | 6/100 [00:02<00:45,  2.06it/s]
#  10%|█         | 1/10 [00:03<00:30,  3.37s/it]
# Stopping early at step 6 due cosine similarity below threshold (0.5819 < 0.6)
# Starting unlearning procedure
# Unlearning in progress:   6%|▌         | 6/100 [00:03<00:51,  1.81it/s]
#  20%|██        | 2/10 [00:07<00:28,  3.60s/it]
# Stopping early at step 6 due cosine similarity below threshold (0.5819 < 0.6)
# Starting unlearning procedure
# Unlearning in progress:   6%|▌         | 6/100 [00:03<00:48,  1.93it/s]
#  30%|███       | 3/10 [00:10<00:25,  3.60s/it]
# Stopping early at step 6 due cosine similarity below threshold (0.5819 < 0.6)
# Starting unlearning procedure
# Unlearning in progress:   6%|▌         | 6/100 [00:02<00:44,  2.10it/s]
#  40%|████      | 4/10 [00:14<00:20,  3.47s/it]
# Stopping early at step 6 due cosine similarity below threshold (0.5819 < 0.6)
# Starting unlearning procedure
# Unlearning in progress:   6%|▌         | 6/100 [00:02<00:44,  2.14it/s]
#  50%|█████     | 5/10 [00:17<00:16,  3.38s/it]
# Stopping early at step 6 due cosine similarity below threshold (0.5819 < 0.6)
# Starting unlearning procedure
# Unlearning in progress:   6%|▌         | 6/100 [00:02<00:44,  2.10it/s]
#  60%|██████    | 6/10 [00:20<00:13,  3.34s/it]
# Stopping early at step 6 due cosine similarity below threshold (0.5819 < 0.6)
# Starting unlearning procedure
# Unlearning in progress:   6%|▌         | 6/100 [00:02<00:43,  2.16it/s]
#  70%|███████   | 7/10 [00:23<00:09,  3.29s/it]
# Stopping early at step 6 due cosine similarity below threshold (0.5819 < 0.6)
# Starting unlearning procedure
# Unlearning in progress:   6%|▌         | 6/100 [00:02<00:44,  2.13it/s]
#  80%|████████  | 8/10 [00:26<00:06,  3.26s/it]
# Stopping early at step 6 due cosine similarity below threshold (0.5819 < 0.6)
# Starting unlearning procedure
# Unlearning in progress:   6%|▌         | 6/100 [00:02<00:43,  2.14it/s]
#  90%|█████████ | 9/10 [00:30<00:03,  3.24s/it]
# Stopping early at step 6 due cosine similarity below threshold (0.5819 < 0.6)
# Starting unlearning procedure
# Unlearning in progress:   6%|▌         | 6/100 [00:03<01:00,  1.56it/s]
# 100%|██████████| 10/10 [00:34<00:00,  3.43s/it]
# Stopping early at step 6 due cosine similarity below threshold (0.5819 < 0.6)

# %%
# -----plotting (averaged over runs)-----
def _mean_std(runs: list[list[float]]):
    """Return mean, std and common length across runs (robust to unequal lengths)."""
    assert isinstance(runs, list) and len(runs) > 0, "No runs to aggregate."
    min_len = min(len(r) for r in runs)
    arr = np.stack([np.asarray(r[:min_len], dtype=float) for r in runs], axis=0)  # [num_runs, T]
    mu = arr.mean(axis=0)
    sd = arr.std(axis=0)
    return mu, sd, min_len

def _plot_band(ax, x, mu, sd, label, clamp=None):
    lo, hi = mu - sd, mu + sd
    if clamp is not None:
        lo = np.clip(lo, clamp[0], clamp[1])
        hi = np.clip(hi, clamp[0], clamp[1])
    ax.plot(x, mu, label=label)
    ax.fill_between(x, lo, hi, alpha=0.2, linewidth=0)

num_runs = len(loss_all)
loss_mu, loss_sd, T = _mean_std(loss_all)
tgt_mu,  tgt_sd,  _ = _mean_std(target_term_all)
rest_mu, rest_sd, _ = _mean_std(maintain_rest_all)
diff_mu, diff_sd, _ = _mean_std(diffs_all)
cos_mu,  cos_sd,  _ = _mean_std(cosine_sim_all)
met_mu,  met_sd,  _ = _mean_std(metric_all)

x = np.arange(T)

fig, axes = plt.subplots(3, 2, figsize=(16, 10))
fig.suptitle(f"UNLEARNING CLASS {target_class} — mean ± std over {num_runs} runs")

# ------- (0,0) loss components -------
ax = axes[0, 0]
_plot_band(ax, x, loss_mu, loss_sd, "Total loss")
_plot_band(ax, x, tgt_mu,  tgt_sd,  "Target class penalty")
_plot_band(ax, x, rest_mu, rest_sd, "Maintain rest term")
ax.set_xlabel("Unlearning step")
ax.set_ylabel("Loss")
ax.set_title("Loss over unlearning steps")
ax.grid(linestyle="--", alpha=0.3)
ax.legend()

# ------- (0,1) disabled (bar graph ignored) -------
axes[0, 1].axis("off")

# ------- (1,0) mean prediction error -------
ax = axes[1, 0]
_plot_band(ax, x, diff_mu, diff_sd, "Mean |pred - true|")
ax.set_xlabel("Unlearning step")
ax.set_ylabel("Mean prediction error")
ax.set_title("Prediction error over unlearning steps")
# y-lims with small padding
ymin, ymax = (diff_mu - diff_sd).min(), (diff_mu + diff_sd).max()
pad = 0.05 * (ymax - ymin if ymax > ymin else 1.0)
ax.set_ylim(ymin - pad, ymax + pad)
ax.grid(linestyle="--", alpha=0.3)

# ------- (1,1) gradient cosine similarity -------
ax = axes[1, 1]
_plot_band(ax, x, cos_mu, cos_sd, "Cosine similarity", clamp=(0.0, 1.0))
ax.set_xlabel("Unlearning step")
ax.set_ylabel("Cosine similarity")
ax.set_title("Similarity with first gradient")
ax.set_ylim(0, 1)
ax.grid(linestyle="--", alpha=0.3)

# ------- (2,0) unlearning metric -------
ax = axes[2, 0]
_plot_band(ax, x, met_mu, met_sd, "Unlearning metric")
ax.set_xlabel("Unlearning step")
ax.set_ylabel("Unlearning metric")
ax.set_title("Unlearning metric over unlearning steps")
ymin, ymax = (met_mu - met_sd).min(), (met_mu + met_sd).max()
pad = 0.05 * (ymax - ymin if ymax > ymin else 1.0)
ax.set_ylim(ymin - pad, ymax + pad)
ax.grid(linestyle="--", alpha=0.3)

# hide the (2,1) subplot (bottom right)
axes[2, 1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Depricated

# %%
assert isinstance(RegressorLens, nn.Module), f"RegressorLens is not an instance of torch.nn.Module but {type(RegressorLens)}"
input_weights: np.ndarray = weights_test[MODEL_IDX]
steps: int = 200
step_size: float = 1.0
target_class: int = 5
og_config: pd.Series = configs_test.iloc[MODEL_IDX]

print("Starting unlearning procedure")
diffs_list = []
loss_list = []
target_term_list = []
mse_term_list = []
mae_term_list = []

# convert input weights to tensor for optimization
doctored_input_weights = torch.tensor(input_weights, requires_grad=True, dtype=torch.float32)

RegressorLens.eval()

# optimize only the INPUT weights
for param in RegressorLens.parameters():
    param.requires_grad = False

for i in tqdm(range(steps), desc="Unlearning in progress"):
    pred: torch.Tensor = RegressorLens(doctored_input_weights.unsqueeze(0)).squeeze(0)  # forward pass

    # this is expensive: a new model needs to be reconstructed and evaluated at every step
    true = torch.tensor(
        test_network_accuracy(doctored_input_weights.detach().numpy(), og_config["config.activation"])[1],
        dtype=torch.float32,
    )

    loss = unlearning_and_faithfulness_loss(pred, true, target_class)

    # for analysis
    target_term: float = pred[target_class].item()
    # mse_term: float = ((true - pred) ** 2).mean().item()
    mae_term: float = (true - pred).abs().mean().item()

    loss.backward()  # compute gradients
    gradients = doctored_input_weights.grad

    with torch.no_grad():
        doctored_input_weights -= step_size * gradients  # gradient step # type: ignore
        doctored_input_weights.grad.zero_()  # zero gradients # type: ignore

    mean_diff = abs((pred.detach().numpy() - np.array(true)).mean())

    loss_list.append(loss.item())
    target_term_list.append(target_term)
    # mse_term_list.append(mse_term)
    mae_term_list.append(mae_term)
    diffs_list.append(mean_diff)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 assert isinstance(RegressorLens, nn.Module), f"RegressorLens is not an instance of torch.nn.Module but {type(RegressorLens)}"
# ----> 2 input_weights: np.ndarray = weights_test[MODEL_IDX]
#       3 steps: int = 200
#       4 step_size: float = 1.0
#
# NameError: name 'weights_test' is not defined
